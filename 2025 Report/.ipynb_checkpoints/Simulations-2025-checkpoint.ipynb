# %%
import pandas as pd
import numpy as np
import random
pd.set_option('display.max_columns', None)
# Out:
# /var/folders/kl/zk6vhzq10g1dwngp4jd35vvr0000gp/T/ipykernel_18420/3098046952.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was too old on your system - pyarrow 10.0.1 is the current minimum supported version as of this release.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
FF_2025 = pd.read_excel('../LeagueHistory.xlsx', sheet_name='2025')
FF_2025_summary = FF_2025[['Team_Name', 'Mean']].drop(index=12)

# %%
FF_2025
# Out:
#                     Team_Name  Week 1      Week 2      Week 3      Week 4  \
# 0           GOBias Industries  145.62  123.280000   92.160000  105.900000
# 1              Herbin Legends   93.58   78.440000  115.640000  120.100000
# 2            Blunt Dissection   77.84  141.780000  139.860000  135.100000
# 3                     Schmaap  102.62  115.640000   91.980000  116.460000
# 4            Fuck wit Tre Day  122.66   76.120000  121.220000  112.460000
# 5        Mr. Fans Noodle Haus  119.12  114.480000   92.620000   96.780000
# 6         Pay Dirt & Pylons V  113.20  114.860000  140.820000  115.080000
# 7   Grip Hamilton Memorial 5k  104.88  196.400000   84.320000  114.180000
# 8     Tony Horton Hears a Who   98.62  122.000000  117.200000  107.920000
# 9            Gee Whiz Darnell  113.36  116.700000  130.820000  106.180000
# 10              Pierogi Night   92.52  127.440000   90.240000  126.160000
# 11              Sackwash Lyfe   93.62   60.740000  106.560000  156.840000
# ...

# %%
FF_2025_summary
# Out:
#                     Team_Name        Mean
# 0           GOBias Industries  122.954286
# 1              Herbin Legends  121.935714
# 2            Blunt Dissection  121.145714
# 3                     Schmaap  113.017143
# 4            Fuck wit Tre Day  115.128571
# 5        Mr. Fans Noodle Haus  107.037143
# 6         Pay Dirt & Pylons V  104.765714
# 7   Grip Hamilton Memorial 5k  102.971429
# 8     Tony Horton Hears a Who  119.354286
# 9            Gee Whiz Darnell  109.362857
# 10              Pierogi Night  108.954286
# 11              Sackwash Lyfe  104.668571

# %%
std = 20.3
games = 14

def simulate_one_season_scores(df):
    Wolf_scores = np.random.normal(df.loc[0, 'Mean'], std, games)
    Brand_scores = np.random.normal(df.loc[1, 'Mean'], std, games)
    Eli_scores = np.random.normal(df.loc[2, 'Mean'], std, games)
    Burnett_scores = np.random.normal(df.loc[3, 'Mean'], std, games)

    Todd_scores = np.random.normal(df.loc[4, 'Mean'], std, games)
    Jay_scores = np.random.normal(df.loc[5, 'Mean'], std, games)
    Cam_scores = np.random.normal(df.loc[6, 'Mean'], std, games)
    Kevin_scores = np.random.normal(df.loc[7, 'Mean'], std, games)
    
    Will_scores = np.random.normal(df.loc[8, 'Mean'], std, games)
    Brenton_scores = np.random.normal(df.loc[9, 'Mean'], std, games)
    Mike_scores = np.random.normal(df.loc[10, 'Mean'], std, games)
    Tommy_scores = np.random.normal(df.loc[11, 'Mean'], std, games)

    
    SCORES = np.array([Wolf_scores, Brand_scores, Eli_scores, Burnett_scores, 
                       Todd_scores, Jay_scores, Cam_scores, Kevin_scores, 
                       Will_scores, Brenton_scores, Mike_scores, Tommy_scores])
    return(SCORES)

# %%
def week1(scores_array, wins_array):
    weekindex = 0

    matchups = [
        (9, 11),   # Brenton vs Tommy
        (10, 2),   # Mike vs Eli
        (4, 0),    # Todd vs Wolf
        (8, 6),    # Will vs Cam
        (7, 3),    # Kevin vs Burnett
        (1, 5)     # Brand vs Jay
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week2(scores_array, wins_array):
    
    weekindex = 1

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 0),   # Brenton vs Wolf
        (10, 5),   # Mike vs Jay
        (4, 8),    # Todd vs Will
        (2, 11),   # Eli vs Tommy
        (7, 6),    # Kevin vs Cam
        (1, 3)     # Brand vs Burnett
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week3(scores_array, wins_array):
    
    weekindex = 2

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 8),   # Brenton vs Will
        (10, 1),   # Mike vs Brand
        (4, 7),    # Todd vs Kevin
        (2, 0),   # Eli vs Wolf
        (5, 11),    # Jay vs Tommy
        (6, 3)     # Cam vs Burnett
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week4(scores_array, wins_array):
    
    weekindex = 3

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 7),    # Brenton vs Kevin
        (10, 11),  # Mike vs Tommy
        (4, 3),    # Todd vs Burnett
        (2, 8),    # Eli vs Will
        (0, 5),    # Wolf vs Jay
        (1, 6)     # Brand vs Cam
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week5(scores_array, wins_array):
    
    weekindex = 4

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 3),    # Brenton vs Burnett
        (10, 0),  # Mike vs Wolf
        (4, 6),    # Todd vs Cam
        (2, 7),    # Eli vs Kevin
        (8, 5),    # Will vs Jay
        (1, 11)     # Brand vs Tommy
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week6(scores_array, wins_array):
    
    weekindex = 5

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 6),    # Brenton vs Cam
        (10, 8),  # Mike vs Will
        (4, 1),    # Todd vs Brand
        (2, 3),    # Eli vs Burnett
        (0, 11),    # Wolf vs Tommy
        (7, 5)     # Kevin vs Jay
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week7(scores_array, wins_array):
    
    weekindex = 6

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 4),    # Brenton vs Todd
        (10, 7),  # Mike vs Kevin
        (2, 6),    # Eli vs Cam
        (8, 11),    # Will vs Tommy
        (0, 1),    # Wolf vs Brand
        (5, 3)     # Jay vs Burnett
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week8(scores_array, wins_array):
    
    weekindex = 7

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 1),    # Brenton vs Brand
        (10, 3),  # Mike vs Burnett
        (4, 2),    # Todd vs Eli
        (8, 0),    # Will vs Wolf
        (7, 11),    # Kevin vs Tommy
        (5, 6)     # Jay vs Cam
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week9(scores_array, wins_array):
    
    weekindex = 8

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 2),    # Brenton vs Eli
        (10, 6),  # Mike vs Cam
        (4, 5),    # Todd vs Jay
        (8, 1),    # Will vs Brand
        (0, 7),    # Wolf vs Kevin
        (11, 3)     # Tommy vs Burnett
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week10(scores_array, wins_array):
    
    weekindex = 9

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 5),    # Brenton vs Jay
        (10, 4),  # Mike vs Todd
        (2, 1),    # Eli vs Brand
        (8, 7),    # Will vs Kevin
        (0, 3),    # Wolf vs Burnett
        (6, 11)     #Cam vs Tommy
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week11(scores_array, wins_array):
    
    weekindex = 10

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 10),   # Brenton vs Mike
        (4, 11),   # Todd vs Tommy
        (2, 5),    # Eli vs Jay
        (8, 3),    # Will vs Burnett
        (0, 6),    # Wolf vs Cam
        (7, 1)    # Kevin vs Brand
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week12(scores_array, wins_array):
    weekindex = 11

    matchups = [
        (9, 11),   # Brenton vs Tommy
        (10, 2),   # Mike vs Eli
        (4, 0),    # Todd vs Wolf
        (8, 6),    # Will vs Cam
        (7, 3),    # Kevin vs Burnett
        (1, 5)     # Brand vs Jay
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week13(scores_array, wins_array):
    
    weekindex = 12

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 0),   # Brenton vs Wolf
        (10, 5),   # Mike vs Jay
        (4, 8),    # Todd vs Will
        (2, 11),   # Eli vs Tommy
        (7, 6),    # Kevin vs Cam
        (1, 3)     # Brand vs Burnett
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week14(scores_array, wins_array):
    
    weekindex = 13

    Teams = {'Wolf':0, 'Brand':1, 'Eli':2, 'Burnett':3, 
             'Todd':4, 'Jay':5, 'Cam':6,'Kevin':7, 
             'Will':8, 'Brenton':9, 'Mike':10, 'Tommy': 11} 
    
    matchups = [
        (9, 8),   # Brenton vs Will
        (10, 1),   # Mike vs Brand
        (4, 7),    # Todd vs Kevin
        (2, 0),   # Eli vs Wolf
        (5, 11),    # Jay vs Tommy
        (6, 3)     # Cam vs Burnett
    ]

    for team_a, team_b in matchups:
        if scores_array[team_a][weekindex] > scores_array[team_b][weekindex]:
            wins_array[team_a] += 1
        else:
            wins_array[team_b] += 1

    return wins_array

# %%
def week_fair(scores_array, wins_array, week = 12):
    
    p = np.arange(12)
    random.shuffle(p)
    
    for n in range(6):
        first = p[2*n]
        second = p[2*n+1]
    
        if scores_array[first][week-1] > scores_array[second][week-1]:
            wins_array[first] = wins_array[first] + 1
        else:
            wins_array[second] = wins_array[second] + 1
    
    return wins_array

# %%
def simulate_one_season_matchups(scoring_array, fair=False):
    wins_array = np.zeros(12)
    
    WINS1 = week1(scoring_array, wins_array.copy())
    WINS2 = week2(scoring_array, WINS1.copy())
    WINS3 = week3(scoring_array, WINS2.copy())
    WINS4 = week4(scoring_array, WINS3.copy())
    WINS5 = week5(scoring_array, WINS4.copy())
    WINS6 = week6(scoring_array, WINS5.copy())
    WINS7 = week7(scoring_array, WINS6.copy())
    WINS8 = week8(scoring_array, WINS7.copy())
    WINS9 = week9(scoring_array, WINS8.copy())
    WINS10 = week10(scoring_array, WINS9.copy())
    WINS11 = week11(scoring_array, WINS10.copy())
        
    if fair==False:
        WINS12 = week12(scoring_array, WINS11.copy())
        WINS13 = week13(scoring_array, WINS12.copy())
        wins_per_team = tuple(week14(scoring_array, WINS13.copy()))
    elif fair==True:
        WINS12 = week_fair(scoring_array, WINS11.copy(), week=12)
        WINS13 = week_fair(scoring_array, WINS12.copy(), week=13)
        wins_per_team = tuple(week_fair(scoring_array, WINS13.copy(), week=14))

    
    #return final results
    losses_per_team = tuple([14-w for w in wins_per_team])
    score_per_team = tuple(scoring_array.sum(axis=1))
    label_per_team =  tuple(FF_2025_summary['Team_Name'])
    standings = pd.DataFrame(np.vstack((wins_per_team, losses_per_team, score_per_team)).T, index=label_per_team)
    standings = standings.rename(columns={0:'W', 1:'L', 2:'Pts'})    
    
    standings['Pts'] = standings['Pts'].astype(float)
    standings = standings.sort_values(by=['W', 'Pts'], ascending=[False, False])
    
    standings['Place'] = np.arange(1,13)
    standings['Playoffs'] = np.where(standings['Place'] < 7, 1, 0)
    standings['Bye'] = np.where(standings['Place'] < 3, 1, 0)
    standings['Sacko'] = np.where(standings['Place'] > 11, 1, 0)
    
    places = np.array(standings['Place'])
    playoffs = np.array(standings['Playoffs'])
    byes = np.array(standings['Bye'])
    sackos = np.array(standings['Sacko'])
    
    return standings

# %%
simulate_one_season_matchups(simulate_one_season_scores(FF_2025_summary))
# Out:
#                               W     L          Pts  Place  Playoffs  Bye  \
# GOBias Industries          13.0   1.0  1791.514243      1         1    1
# Blunt Dissection           10.0   4.0  1741.461973      2         1    1
# Tony Horton Hears a Who    10.0   4.0  1720.945568      3         1    0
# Fuck wit Tre Day            8.0   6.0  1609.429236      4         1    0
# Herbin Legends              7.0   7.0  1608.744260      5         1    0
# Gee Whiz Darnell            7.0   7.0  1594.128328      6         1    0
# Pierogi Night               6.0   8.0  1514.647441      7         0    0
# Sackwash Lyfe               6.0   8.0  1474.830002      8         0    0
# Schmaap                     6.0   8.0  1429.291532      9         0    0
# Grip Hamilton Memorial 5k   5.0   9.0  1460.854063     10         0    0
# Mr. Fans Noodle Haus        4.0  10.0  1348.313665     11         0    0
# Pay Dirt & Pylons V         2.0  12.0  1404.787298     12         0    0
#
# ...

# %%
def simulate_many_seasons(FF_summary, sims = 2, fair=False):
    '''
    @sims is the number of simulations you would like to run.
    '''
    SCORES = simulate_one_season_scores(FF_summary)
    TOTAL = simulate_one_season_matchups(SCORES, fair=fair)
    
    for i in range(1,sims):
            
        SCORES = simulate_one_season_scores(FF_summary)
        SEASON_DF = simulate_one_season_matchups(SCORES, fair=fair)
        
        for col in TOTAL.columns.values:
            TOTAL[col] = TOTAL[col]/(i+1)*i + SEASON_DF[col]/(i+1) #Average is continuously updated across trials
    return TOTAL

def clean_total(total):
    total['W'] = round(total['W'], 2)
    total['L'] = 14-total['W']
    total['Pts'] = round(total['Pts'], 2)
    total['Place'] = round(total['Place'], 2)
    total['Playoffs'] = round(total['Playoffs'], 3)*100
    total['Bye'] = round(total['Bye'], 3)*100
    total['Sacko'] = round(total['Sacko'], 3)*100
    total = total.sort_values(by='Place')
    return total

# %% [markdown]
# # Run simulations

# %%
Sims_raw = simulate_many_seasons(FF_2025_summary, sims = 100000)
Sims = clean_total(Sims_raw)

# %%
print(sum(Sims['W']), sum(Sims['L']))
Sims
# Out:
# 84.02000000000001 83.97999999999999
#                               W     L      Pts  Place  Playoffs   Bye  Sacko
# GOBias Industries          8.95  5.05  1721.31   3.32      89.5  46.0    0.2
# Herbin Legends             8.98  5.02  1706.96   3.35      89.2  45.3    0.2
# Blunt Dissection           8.73  5.27  1696.28   3.67      86.6  39.3    0.3
# Tony Horton Hears a Who    8.49  5.51  1670.89   4.07      82.7  32.4    0.5
# Fuck wit Tre Day           7.41  6.59  1611.87   5.72      62.2  13.6    2.1
# Schmaap                    7.20  6.80  1582.18   6.18      55.7  10.4    3.0
# Gee Whiz Darnell           6.23  7.77  1530.78   7.74      32.3   3.8    8.1
# Pierogi Night              6.10  7.90  1525.16   7.94      30.1   3.3    9.3
# Mr. Fans Noodle Haus       5.91  8.09  1498.64   8.33      25.2   2.5   12.3
# Pay Dirt & Pylons V        5.46  8.54  1466.64   9.04      17.2   1.4   18.9
# Sackwash Lyfe              5.42  8.58  1465.61   9.10      16.6   1.3   19.5
# ...

# %%
Sims2 = simulate_many_seasons(FF_2025_summary, sims = 100000, fair=True)
Sims2 = clean_total(Sims2)

# %%
print(sum(Sims2['W']), sum(Sims2['L']))
Sims2
# Out:
# 84.0 84.0
#                               W     L      Pts  Place  Playoffs   Bye  Sacko
# GOBias Industries          9.09  4.91  1721.35   3.18      90.6  48.9    0.2
# Herbin Legends             8.89  5.11  1707.50   3.46      88.4  43.4    0.3
# Blunt Dissection           8.74  5.26  1696.09   3.67      86.6  39.2    0.3
# Tony Horton Hears a Who    8.38  5.62  1671.02   4.20      81.5  30.2    0.5
# Fuck wit Tre Day           7.53  6.47  1612.13   5.58      64.2  14.8    1.9
# Schmaap                    7.08  6.92  1582.29   6.33      53.2   9.7    3.3
# Gee Whiz Darnell           6.34  7.66  1531.15   7.59      34.7   4.2    7.5
# Pierogi Night              6.24  7.76  1525.29   7.77      32.3   3.8    8.3
# Mr. Fans Noodle Haus       5.87  8.13  1498.47   8.37      24.3   2.4   12.3
# Pay Dirt & Pylons V        5.40  8.60  1466.36   9.11      16.5   1.3   19.3
# Sackwash Lyfe              5.39  8.61  1465.59   9.13      16.2   1.3   19.7
# ...

# %%
Sims.to_excel('SimsMatchup25.xlsx')
Sims2.to_excel('SimsRandom25.xlsx')
