# %%
import pandas as pd
import numpy as np
import random
pd.set_option('display.max_columns', None)

# %%
FF_2024 = pd.read_excel('../LeagueHistory.xlsx', sheet_name='2024')
FF_2024_summary = FF_2024[['Team_Name', 'Mean']].drop(12, 0)

# %%
FF_2024_summary
# Out:
#                          Team_Name        Mean
# 0                GOBias Industries  123.558667
# 1                          Schmaap  121.488000
# 2                    Pierogi Night  114.866667
# 3             Mr. Fans Noodle Haus  113.776000
# 4        Grip Hamilton Memorial 5k  107.446667
# 5                      New Drywall  124.857333
# 6             Pay Dirt & Pylons IV  123.286667
# 7                           8Chane  110.333333
# 8            Bijan the second date  106.857333
# 9                   Herbin Legends   98.569333
# 10                Gee Whiz Darnell  101.113333
# 11  Brady come back u can blame it  106.452000

# %%
std = 20.3
games = 15

def simulate_one_season_scores(df):
    Wolf_scores = np.random.normal(df.loc[0, 'Mean'], std, games)
    Burnett_scores = np.random.normal(df.loc[1, 'Mean'], std, games)
    Mike_scores = np.random.normal(df.loc[2, 'Mean'], std, games)
    Jay_scores = np.random.normal(df.loc[3, 'Mean'], std, games)

    Kevin_scores = np.random.normal(df.loc[4, 'Mean'], std, games)
    Tommy_scores = np.random.normal(df.loc[5, 'Mean'], std, games)
    Cam_scores = np.random.normal(df.loc[6, 'Mean'], std, games)
    Todd_scores = np.random.normal(df.loc[7, 'Mean'], std, games)
    
    Eli_scores = np.random.normal(df.loc[8, 'Mean'], std, games)
    Brand_scores = np.random.normal(df.loc[9, 'Mean'], std, games)
    Brenton_scores = np.random.normal(df.loc[10, 'Mean'], std, games)
    Will_scores = np.random.normal(df.loc[11, 'Mean'], std, games)


    
    SCORES = np.array([Wolf_scores, Burnett_scores, Mike_scores, Jay_scores, 
                       Kevin_scores, Tommy_scores, Cam_scores, Todd_scores, 
                       Eli_scores, Brand_scores, Brenton_scores, Will_scores])
    return(SCORES)

# %%
def week1(scores_array, wins_array):
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 0 
    
    #Brenton vs. Todd
    if scores_array[10][weekindex] > scores_array[7][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[7] = wins_array[7] + 1
    
    #Burnett vs. Eli   
    if scores_array[1][weekindex] > scores_array[8][weekindex]:
        wins_array[1] = wins_array[1] + 1
    else:
        wins_array[8] = wins_array[8] + 1
    
    #Brand vs. Cam
    if scores_array[9][weekindex] > scores_array[6][weekindex]:
        wins_array[9] = wins_array[9] + 1
    else:
        wins_array[6] = wins_array[6] + 1
        
    #Kevin vs. Mike
    if scores_array[4][weekindex] > scores_array[2][weekindex]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[2] = wins_array[2] + 1
        
    #Jay vs. Will
    if scores_array[3][weekindex] > scores_array[11][weekindex]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[11] = wins_array[11] + 1
    
    #Wolf vs. Tommy
    if scores_array[0][weekindex] > scores_array[5][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    return wins_array

# %%
def week2(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 1 
    
    #Tommy vs. Brand
    if scores_array[5][weekindex] > scores_array[9][weekindex]:
        wins_array[5] = wins_array[5] + 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Mike vs. Brenton   
    if scores_array[2][weekindex] > scores_array[10][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[10] = wins_array[10] + 1
    
    #Will vs. Eli
    if scores_array[11][weekindex] > scores_array[8][weekindex]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[8] = wins_array[8] + 1
        
    #Wolf vs. Kevin
    if scores_array[0][weekindex] > scores_array[4][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[4] = wins_array[4] + 1
        
    #Cam vs. Burnett
    if scores_array[6][weekindex] > scores_array[1][weekindex]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Todd vs. Jay
    if scores_array[7][weekindex] > scores_array[3][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[3] = wins_array[3] + 1
        
    return wins_array

# %%
def week3(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 2 
    
    #Kevin vs. Brenton
    if scores_array[4][weekindex] > scores_array[10][weekindex]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[10] = wins_array[10] + 1
    
    #Tommy vs. Burnett   
    if scores_array[5][weekindex] > scores_array[1][weekindex]:
        wins_array[5] = wins_array[5] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Eli vs. Todd
    if scores_array[8][weekindex] > scores_array[7][weekindex]:
        wins_array[8] = wins_array[8] + 1
    else:
        wins_array[7] = wins_array[7] + 1
        
    #Wolf vs. Brand
    if scores_array[0][weekindex] > scores_array[9][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[9] = wins_array[9] + 1
        
    #Cam vs. Will
    if scores_array[6][weekindex] > scores_array[11][weekindex]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[11] = wins_array[11] + 1
    
    #Jay vs. Mike
    if scores_array[3][weekindex] > scores_array[2][weekindex]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[2] = wins_array[2] + 1
        
    return wins_array

# %%
def week4(scores_array, wins_array):
       
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 3 
    
    #Brenton vs. Jay
    if scores_array[10][weekindex] > scores_array[3][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[3] = wins_array[3] + 1
    
    #Mike vs. Eli   
    if scores_array[2][weekindex] > scores_array[8][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[8] = wins_array[8] + 1
    
    #Todd vs. Cam
    if scores_array[7][weekindex] > scores_array[6][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[6] = wins_array[6] + 1
        
    #Will vs. Tommy
    if scores_array[11][weekindex] > scores_array[5][weekindex]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    #Wolf vs. Burnett
    if scores_array[0][weekindex] > scores_array[1][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Brand vs. Kevin
    if scores_array[9][weekindex] > scores_array[4][weekindex]:
        wins_array[9] = wins_array[9] + 1
    else:
        wins_array[4] = wins_array[4] + 1
        
    return wins_array

# %%
def week5(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 4 
    
    #Brenton vs. Eli
    if scores_array[10][weekindex] > scores_array[8][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[8] = wins_array[8] + 1
    
    #Mike vs. Cam   
    if scores_array[2][weekindex] > scores_array[6][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[6] = wins_array[6] + 1
    
    #Todd vs. Tommy
    if scores_array[7][weekindex] > scores_array[5][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    #Will vs. Schulwolf
    if scores_array[11][weekindex] > scores_array[0][weekindex]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[0] = wins_array[0] + 1
        
    #Brand vs. Burnett
    if scores_array[9][weekindex] > scores_array[1][weekindex]:
        wins_array[9] = wins_array[9] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Jay vs. Kevin
    if scores_array[3][weekindex] > scores_array[4][weekindex]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[4] = wins_array[4] + 1
        
    return wins_array

# %%
def week6(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 5
    
    #Brenton vs. Cam
    if scores_array[10][weekindex] > scores_array[6][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[6] = wins_array[6] + 1
    
    #Mike vs. Tommy   
    if scores_array[2][weekindex] > scores_array[5][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[5] = wins_array[5] + 1
    
    #Todd vs. Wolf
    if scores_array[7][weekindex] > scores_array[0][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[0] = wins_array[0] + 1
        
    #Eli vs. Jay
    if scores_array[8][weekindex] > scores_array[3][weekindex]:
        wins_array[8] = wins_array[8] + 1
    else:
        wins_array[3] = wins_array[3] + 1
        
    #Will vs. Brand
    if scores_array[11][weekindex] > scores_array[9][weekindex]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Kevin vs. Burnett
    if scores_array[4][weekindex] > scores_array[1][weekindex]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[1] = wins_array[1] + 1
        
    return wins_array

# %%
def week7(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 6 
    
    #Brenton vs. Tommy
    if scores_array[10][weekindex] > scores_array[5][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[5] = wins_array[5] + 1
    
    #Mike vs. Wolf   
    if scores_array[2][weekindex] > scores_array[0][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[0] = wins_array[0] + 1
    
    #Todd vs. Brand
    if scores_array[7][weekindex] > scores_array[9][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[9] = wins_array[9] + 1
        
    #Eli vs. Kevin
    if scores_array[8][weekindex] > scores_array[4][weekindex]:
        wins_array[8] = wins_array[8] + 1
    else:
        wins_array[4] = wins_array[4] + 1
        
    #Will vs. Burnett
    if scores_array[11][weekindex] > scores_array[1][weekindex]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Jay vs. Cam
    if scores_array[3][weekindex] > scores_array[6][weekindex]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[6] = wins_array[6] + 1
        
    return wins_array

# %%
def week8(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 7
    
    #Brenton vs. Wolf
    if scores_array[10][weekindex] > scores_array[0][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[0] = wins_array[0] + 1
    
    #Mike vs. Brand   
    if scores_array[2][weekindex] > scores_array[9][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Todd vs. Burnett
    if scores_array[7][weekindex] > scores_array[1][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[1] = wins_array[1] + 1
        
    #Eli vs. Cam
    if scores_array[8][weekindex] > scores_array[6][weekindex]:
        wins_array[8] = wins_array[8] + 1
    else:
        wins_array[6] = wins_array[6] + 1
        
    #Will vs. Kevin
    if scores_array[11][weekindex] > scores_array[4][weekindex]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[4] = wins_array[4] + 1
    
    #Jay vs. Tommy
    if scores_array[3][weekindex] > scores_array[5][weekindex]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    return wins_array

# %%
def week9(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 8
    
    #Brenton vs. Brand
    if scores_array[10][weekindex] > scores_array[9][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Mike vs. Burnett   
    if scores_array[2][weekindex] > scores_array[1][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Todd vs. Will
    if scores_array[7][weekindex] > scores_array[11][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[11] = wins_array[11] + 1
        
    #Eli vs. Tommy
    if scores_array[8][weekindex] > scores_array[5][weekindex]:
        wins_array[8] = wins_array[8] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    #Wolf vs. Jay
    if scores_array[0][weekindex] > scores_array[3][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[3] = wins_array[3] + 1
    
    #Cam vs. Kevin
    if scores_array[6][weekindex] > scores_array[4][weekindex]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[4] = wins_array[4] + 1
        
    return wins_array

# %%
def week10(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 9
    
    #Brenton vs. Burnett
    if scores_array[10][weekindex] > scores_array[1][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Mike vs. Will   
    if scores_array[2][weekindex] > scores_array[11][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[11] = wins_array[11] + 1
    
    #Todd vs. Kevin
    if scores_array[7][weekindex] > scores_array[4][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[4] = wins_array[4] + 1
        
    #Eli vs. Wolf
    if scores_array[8][weekindex] > scores_array[0][weekindex]:
        wins_array[8] = wins_array[8] + 1
    else:
        wins_array[0] = wins_array[0] + 1
        
    #Brand vs. Jay
    if scores_array[9][weekindex] > scores_array[3][weekindex]:
        wins_array[9] = wins_array[9] + 1
    else:
        wins_array[3] = wins_array[3] + 1
    
    #Cam vs. Tommy
    if scores_array[6][weekindex] > scores_array[5][weekindex]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    return wins_array

# %%
def week11(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 10
    
    #Brenton vs. Will
    if scores_array[10][weekindex] > scores_array[11][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[11] = wins_array[11] + 1
    
    #Mike vs. Todd   
    if scores_array[2][weekindex] > scores_array[7][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[7] = wins_array[7] + 1
    
    #Eli vs. Brand
    if scores_array[8][weekindex] > scores_array[9][weekindex]:
        wins_array[8] = wins_array[8] + 1
    else:
        wins_array[9] = wins_array[9] + 1
        
    #Wolf vs. Cam
    if scores_array[0][weekindex] > scores_array[6][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[6] = wins_array[6] + 1
        
    #Jay vs. Burnett
    if scores_array[3][weekindex] > scores_array[1][weekindex]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Kevin vs. Tommy
    if scores_array[4][weekindex] > scores_array[5][weekindex]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    return wins_array

# %%
def week12(scores_array, wins_array):
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 11 
    
    #Brenton vs. Todd
    if scores_array[10][weekindex] > scores_array[7][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[7] = wins_array[7] + 1
    
    #Burnett vs. Eli   
    if scores_array[1][weekindex] > scores_array[8][weekindex]:
        wins_array[1] = wins_array[1] + 1
    else:
        wins_array[8] = wins_array[8] + 1
    
    #Brand vs. Cam
    if scores_array[9][weekindex] > scores_array[6][weekindex]:
        wins_array[9] = wins_array[9] + 1
    else:
        wins_array[6] = wins_array[6] + 1
        
    #Kevin vs. Mike
    if scores_array[4][weekindex] > scores_array[2][weekindex]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[2] = wins_array[2] + 1
        
    #Jay vs. Will
    if scores_array[3][weekindex] > scores_array[11][weekindex]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[11] = wins_array[11] + 1
    
    #Wolf vs. Tommy
    if scores_array[0][weekindex] > scores_array[5][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    return wins_array

# %%
def week13(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 12 
    
    #Tommy vs. Brand
    if scores_array[5][weekindex] > scores_array[9][weekindex]:
        wins_array[5] = wins_array[5] + 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Mike vs. Brenton   
    if scores_array[2][weekindex] > scores_array[10][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[10] = wins_array[10] + 1
    
    #Will vs. Eli
    if scores_array[11][weekindex] > scores_array[8][weekindex]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[8] = wins_array[8] + 1
        
    #Wolf vs. Kevin
    if scores_array[0][weekindex] > scores_array[4][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[4] = wins_array[4] + 1
        
    #Cam vs. Burnett
    if scores_array[6][weekindex] > scores_array[1][weekindex]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Todd vs. Jay
    if scores_array[7][weekindex] > scores_array[3][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[3] = wins_array[3] + 1
        
    return wins_array

# %%
def week14(scores_array, wins_array):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 13 
    
    #Kevin vs. Brenton
    if scores_array[4][weekindex] > scores_array[10][weekindex]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[10] = wins_array[10] + 1
    
    #Tommy vs. Burnett   
    if scores_array[5][weekindex] > scores_array[1][weekindex]:
        wins_array[5] = wins_array[5] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Eli vs. Todd
    if scores_array[8][weekindex] > scores_array[7][weekindex]:
        wins_array[8] = wins_array[8] + 1
    else:
        wins_array[7] = wins_array[7] + 1
        
    #Wolf vs. Brand
    if scores_array[0][weekindex] > scores_array[9][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[9] = wins_array[9] + 1
        
    #Cam vs. Will
    if scores_array[6][weekindex] > scores_array[11][weekindex]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[11] = wins_array[11] + 1
    
    #Jay vs. Mike
    if scores_array[3][weekindex] > scores_array[2][weekindex]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[2] = wins_array[2] + 1
        
    return wins_array

# %%
def week15(scores_array, wins_array):
       
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    weekindex = 14
    
    #Brenton vs. Jay
    if scores_array[10][weekindex] > scores_array[3][weekindex]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[3] = wins_array[3] + 1
    
    #Mike vs. Eli   
    if scores_array[2][weekindex] > scores_array[8][weekindex]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[8] = wins_array[8] + 1
    
    #Todd vs. Cam
    if scores_array[7][weekindex] > scores_array[6][weekindex]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[6] = wins_array[6] + 1
        
    #Will vs. Tommy
    if scores_array[11][weekindex] > scores_array[5][weekindex]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    #Wolf vs. Burnett
    if scores_array[0][weekindex] > scores_array[1][weekindex]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Brand vs. Kevin
    if scores_array[9][weekindex] > scores_array[4][weekindex]:
        wins_array[9] = wins_array[9] + 1
    else:
        wins_array[4] = wins_array[4] + 1
        
    return wins_array

# %%
def week_fair(scores_array, wins_array, week = 12):
    
    Teams = {'Wolf':0, 'Burnett':1, 'Mike':2, 'Jay':3, 
             'Kevin':4, 'Tommy':5, 'Cam':6,'Todd':7, 
             'Eli':8, 'Brand':9, 'Brenton':10, 'Will': 11} 
    #not used, just for reference

    p = np.arange(12)
    random.shuffle(p)
    
    for n in range(6):
        first = p[2*n]
        second = p[2*n+1]
    
        if scores_array[first][week-1] > scores_array[second][week-1]:
            wins_array[first] = wins_array[first] + 1
        else:
            wins_array[second] = wins_array[second] + 1
    
    return wins_array

# %%
def simulate_one_season_matchups(scoring_array, fair=False):
    wins_array = np.zeros(12)
    WINS1 = week1(scoring_array, wins_array.copy())
    WINS2 = week2(scoring_array, WINS1.copy())
    WINS3 = week3(scoring_array, WINS2.copy())
    WINS4 = week4(scoring_array, WINS3.copy())
    WINS5 = week5(scoring_array, WINS4.copy())
    WINS6 = week6(scoring_array, WINS5.copy())
    WINS7 = week7(scoring_array, WINS6.copy())
    WINS8 = week8(scoring_array, WINS7.copy())
    WINS9 = week9(scoring_array, WINS8.copy())
    WINS10 = week10(scoring_array, WINS9.copy())
    WINS11 = week11(scoring_array, WINS10.copy())
        
    if fair==False:
        WINS12 = week12(scoring_array, WINS11.copy())
        WINS13 = week13(scoring_array, WINS12.copy())
        WINS14 = week14(scoring_array, WINS13.copy())
        wins_per_team = tuple(week15(scoring_array, WINS14.copy()))
    elif fair==True:
        WINS12 = week_fair(scoring_array, WINS11.copy(), week=12)
        WINS13 = week_fair(scoring_array, WINS12.copy(), week=13)
        WINS14 = week_fair(scoring_array, WINS13.copy(), week=14)
        wins_per_team = tuple(week_fair(scoring_array, WINS14.copy(), week=15))
        
    #return final results
    losses_per_team = tuple([15-w for w in wins_per_team])
    score_per_team = tuple(scoring_array.sum(axis=1))
    label_per_team =  tuple(FF_2024_summary['Team_Name'])
    standings = pd.DataFrame(np.vstack((wins_per_team, losses_per_team, score_per_team)).T, index=label_per_team)
    standings = standings.rename(columns={0:'W', 1:'L', 2:'Pts'})    
    
    standings['Pts'] = standings['Pts'].astype(float)
    standings = standings.sort_values(by=['W', 'Pts'], ascending=[False, False])
    
    standings['Place'] = np.arange(1,13)
    standings['Playoffs'] = np.where(standings['Place'] < 5, 1, 0)
    standings['Top'] = np.where(standings['Place'] == 1, 1, 0)
    standings['Sacko'] = np.where(standings['Place'] > 11, 1, 0)
    
    places = np.array(standings['Place'])
    playoffs = np.array(standings['Playoffs'])
    tops = np.array(standings['Top'])
    sackos = np.array(standings['Sacko'])
    
    return standings

# %%
def simulate_many_seasons(FF_summary, sims = 2, fair=False):
    '''
    @sims is the number of simulations you would like to run.
    '''
    SCORES = simulate_one_season_scores(FF_summary)
    TOTAL = simulate_one_season_matchups(SCORES, fair=fair)
    
    for i in range(1,sims):
            
        SCORES = simulate_one_season_scores(FF_summary)
        SEASON_DF = simulate_one_season_matchups(SCORES, fair=fair)
        
        for col in TOTAL.columns.values:
            TOTAL[col] = TOTAL[col]/(i+1)*i + SEASON_DF[col]/(i+1) #Average is continuously updated across trials
    return TOTAL

def clean_total(total):
    total['W'] = round(total['W'], 2)
    total['L'] = 15-total['W']
    total['Pts'] = round(total['Pts'], 2)
    total['Place'] = round(total['Place'], 2)
    total['Playoffs'] = round(total['Playoffs'], 3)*100
    total['Top'] = round(total['Top'], 3)*100
    total['Sacko'] = round(total['Sacko'], 3)*100
    total = total.sort_values(by='Place')
    return total

# %% [markdown]
# # Run simulations

# %%
Sims_raw = simulate_many_seasons(FF_2024_summary, sims = 10000)
Sims = clean_total(Sims_raw)

# %%
print(sum(Sims['W']), sum(Sims['L']))
Sims
# Out:
# 90.00999999999999 89.99
#                                    W      L      Pts  Place  Playoffs   Top  \
# New Drywall                     9.99   5.01  1873.12   2.98      79.7  28.3
# Pay Dirt & Pylons IV            9.87   5.13  1850.07   3.19      77.1  24.2
# GOBias Industries               9.77   5.23  1855.10   3.27      75.2  23.4
# Schmaap                         9.00   6.00  1823.54   4.18      59.5  13.6
# Pierogi Night                   8.24   6.76  1722.49   5.52      36.7   4.6
# Mr. Fans Noodle Haus            7.97   7.03  1705.84   5.91      31.0   3.2
# 8Chane                          7.08   7.92  1655.72   7.18      15.9   1.3
# Grip Hamilton Memorial 5k       6.56   8.44  1611.06   8.00       9.3   0.6
# Bijan the second date           6.24   8.76  1604.96   8.37       7.6   0.4
# Brady come back u can blame it  5.91   9.09  1596.67   8.75       5.5   0.3
# Gee Whiz Darnell                5.12   9.88  1516.41   9.87       1.9   0.1
# Herbin Legends                  4.26  10.74  1477.49  10.79       0.6   0.0
#
#                                 Sacko
# New Drywall                       0.1
# Pay Dirt & Pylons IV              0.0
# GOBias Industries                 0.1
# Schmaap                           0.4
# Pierogi Night                     1.0
# Mr. Fans Noodle Haus              1.0
# 8Chane                            3.7
# Grip Hamilton Memorial 5k         6.5
# Bijan the second date             7.8
# Brady come back u can blame it   10.5
# Gee Whiz Darnell                 23.7
# Herbin Legends                   45.3

# %%
Sims2 = simulate_many_seasons(FF_2024_summary, sims = 100000, fair=True)
Sims2 = clean_total(Sims2)

# %%
print(sum(Sims2['W']), sum(Sims2['L']))
Sims2
# Out:
# 90.00000000000001 90.0
#                                     W      L      Pts  Place  Playoffs   Top  \
# New Drywall                     10.07   4.93  1872.88   2.93      80.7  29.3
# GOBias Industries                9.81   5.19  1853.11   3.24      76.1  23.4
# Pay Dirt & Pylons IV             9.76   5.24  1849.64   3.31      75.1  22.1
# Schmaap                          9.39   5.61  1822.51   3.78      67.3  16.0
# Pierogi Night                    7.96   7.04  1722.74   5.80      32.4   3.7
# Mr. Fans Noodle Haus             7.74   7.26  1706.89   6.14      27.8   2.9
# 8Chane                           6.98   8.02  1655.18   7.27      15.2   1.1
# Grip Hamilton Memorial 5k        6.35   8.65  1611.40   8.19       8.3   0.5
# Bijan the second date            6.23   8.77  1602.68   8.37       7.5   0.4
# Brady come back u can blame it   6.13   8.87  1596.33   8.50       6.8   0.3
# Gee Whiz Darnell                 5.04   9.96  1516.95   9.96       1.8   0.1
# Herbin Legends                   4.54  10.46  1478.98  10.52       0.9   0.0
#
#                                 Sacko
# New Drywall                       0.0
# GOBias Industries                 0.1
# Pay Dirt & Pylons IV              0.1
# Schmaap                           0.2
# Pierogi Night                     1.1
# Mr. Fans Noodle Haus              1.6
# 8Chane                            4.0
# Grip Hamilton Memorial 5k         7.7
# Bijan the second date             8.8
# Brady come back u can blame it    9.8
# Gee Whiz Darnell                 26.4
# Herbin Legends                   40.2

# %%
#Sims.to_excel('SimsMatchup24.xlsx')
Sims2.to_excel('SimsRandom24.xlsx')
