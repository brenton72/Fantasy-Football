# %%
import pandas as pd
import numpy as np
import random
pd.set_option('display.max_columns', None)

# %%
FF_2021 = pd.read_excel('FF_2021.xlsx')
FF_2021_summary = FF_2021[['Team_Name', 'Mean']].drop(12, 0)

# %%
FF_2021_summary
# Out:
#                 Team_Name        Mean
# 0    Jasjaap's Primo Team  121.548000
# 1     Pay Dirt and Pylons  126.109333
# 2       GOBias Industries  120.910667
# 3   Brady = Washed Up III  119.138667
# 4        Gee Whiz Darnell  114.848000
# 5           Sackwash Lyfe  107.330667
# 6              Dak to Dak  120.505333
# 7      Shiva Volodarskaya  110.893333
# 8          Herbin Legends  113.690667
# 9                  Schmop  107.985333
# 10      Champagne or Bust   98.677333
# 11   Mr. Fans Noodle Haus   92.126667

# %%
std = 22
games = 15

def simulate_one_season_scores(df):
    Jasjaap_scores = np.random.normal(df.loc[0, 'Mean'], std, games)
    Cam_scores = np.random.normal(df.loc[1, 'Mean'], std, games)
    Wolf_scores = np.random.normal(df.loc[2, 'Mean'], std, games)
    Will_scores = np.random.normal(df.loc[3, 'Mean'], std, games)
    Brenton_scores = np.random.normal(df.loc[4, 'Mean'], std, games)
    Tommy_scores = np.random.normal(df.loc[5, 'Mean'], std, games)
    Mike_scores = np.random.normal(df.loc[6, 'Mean'], std, games)
    Todd_scores = np.random.normal(df.loc[7, 'Mean'], std, games)
    Herbin_scores = np.random.normal(df.loc[8, 'Mean'], std, games)
    Burnett_scores = np.random.normal(df.loc[9, 'Mean'], std, games)
    Eli_scores = np.random.normal(df.loc[10, 'Mean'], std, games)
    Jay_scores = np.random.normal(df.loc[11, 'Mean'], std, games)
    
    SCORES = np.array([Jasjaap_scores, Cam_scores, Wolf_scores, Will_scores, 
                       Brenton_scores, Tommy_scores, Mike_scores, Todd_scores, 
                       Herbin_scores, Burnett_scores, Eli_scores, Jay_scores])
    return(SCORES)

# %%
simulate_one_season_scores(FF_2021_summary)
# Out:
# array([[ 113.25845029,  146.25457945,   98.51582106,  137.4251155 ,
#          171.09212148,  113.16397876,  117.52690436,  127.85912765,
#          103.09130708,   91.706563  ,  117.5578148 ,  121.55226035,
#          114.83997202,  127.81502134,   78.1275134 ],
#        [  73.66268607,  136.60184574,  147.81119429,  174.46839843,
#          117.07514818,  149.02786754,  132.56434517,  136.44949795,
#          130.06838519,   84.3332345 ,  148.98679674,  126.44495161,
#          107.15320364,  168.29689893,  152.6613903 ],
#        [  83.47728618,  130.4055556 ,   85.62000237,  120.704166  ,
#          135.99765856,  109.21010402,  116.66229099,  145.21157698,
#          119.2473781 ,  133.43250021,   64.02929585,  106.42465562,
#          106.85549764,  110.56878965,  106.38715081],
#        [ 138.06629562,   92.49379192,  126.60909829,  124.78983319,
#           81.19984372,  126.6256748 ,  156.71682827,  125.28540179,
# ...

# %%
def week1(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Mike
    if scores_array[4][0] > scores_array[6][0]:
        wins_array[4] =+ 1
    else:
        wins_array[6] =+ 1
    
    #Wolf vs. Todd    
    if scores_array[2][0] > scores_array[7][0]:
        wins_array[2] =+ 1
    else:
        wins_array[7] =+ 1
    
    #Jasjaap vs. Burnett
    if scores_array[0][0] > scores_array[9][0]:
        wins_array[0] =+ 1
    else:
        wins_array[9] =+ 1
        
    #Eli vs. Tommy
    if scores_array[10][0] > scores_array[5][0]:
        wins_array[10] =+ 1
    else:
        wins_array[5] =+ 1
        
    #Jay vs. Cam
    if scores_array[11][0] > scores_array[1][0]:
        wins_array[11] =+ 1
    else:
        wins_array[1] =+ 1
    
    #Will vs. Herbin
    if scores_array[3][0] > scores_array[8][0]:
        wins_array[3] =+ 1
    else:
        wins_array[8] =+ 1
        
    return wins_array

# %%
def week2(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Herbin
    if scores_array[4][1] > scores_array[8][1]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[8]= wins_array[8] + 1
    
    #Mike vs. Wolf    
    if scores_array[6][1] > scores_array[2][1]:
        wins_array[6] = wins_array[6]+ 1
    else:
        wins_array[2] = wins_array[2]+ 1
    
    #Jasjaap vs. Todd
    if scores_array[0][1] > scores_array[7][1]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[7] = wins_array[7]+ 1
        
    #Eli vs. Burnett
    if scores_array[10][1] > scores_array[9][1]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[9] = wins_array[9]+ 1
    
    #Jay vs. Tommy
    if scores_array[11][1] > scores_array[5][1]:
        wins_array[11] = wins_array[11]+ 1
    else:
        wins_array[5] = wins_array[5]+ 1
    
    #Will vs. Cam
    if scores_array[3][1] > scores_array[1][1]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    return wins_array

# %%
def week3(scores_array, wins_array):
    
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Wolf
    if scores_array[4][2] > scores_array[2][2]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[2] = wins_array[2] + 1
    
    #Mike vs. Jasjaap    
    if scores_array[6][2] > scores_array[0][2]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[0] = wins_array[0] + 1
    
    #Eli vs. Todd
    if scores_array[10][2] > scores_array[7][2]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[7] = wins_array[7] + 1
        
    #Jay vs. Burnett
    if scores_array[11][2] > scores_array[9][2]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Will vs. Tommy
    if scores_array[3][2] > scores_array[5][2]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[5] = wins_array[5] + 1
    
    #Cam vs. Herbin
    if scores_array[1][2] > scores_array[8][2]:
        wins_array[1] = wins_array[1] + 1
    else:
        wins_array[8] = wins_array[8] + 1
    return wins_array

# %%
def week4(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Jasjaap
    if scores_array[4][3] > scores_array[0][3]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[0] = wins_array[0] + 1
    
    #Mike vs. Eli    
    if scores_array[6][3] > scores_array[10][3]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[10] = wins_array[10] + 1
    
    #Wolf vs. Herbin
    if scores_array[2][3] > scores_array[8][3]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[8] = wins_array[8] + 1
           
    #Jay vs. Todd
    if scores_array[11][3] > scores_array[7][3]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[7] = wins_array[7] + 1
    
    #Will vs. Burnett
    if scores_array[3][3] > scores_array[9][3]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[9] = wins_array[9] + 1

    #Cam vs. Tommy
    if scores_array[1][3] > scores_array[5][3]:
        wins_array[1] = wins_array[1] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    return wins_array

# %%
def week5(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Eli
    if scores_array[4][4] > scores_array[10][4]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[10] = wins_array[10] + 1
    
    #Mike vs. Jay    
    if scores_array[6][4] > scores_array[11][4]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[11] = wins_array[11] + 1
    
    #Wolf vs. Jasjaap
    if scores_array[2][4] > scores_array[0][4]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[0] = wins_array[0] + 1
           
    #Will vs. Todd
    if scores_array[3][4] > scores_array[7][4]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[7] = wins_array[7] + 1
    
    #Cam vs. Burnett
    if scores_array[1][4] > scores_array[9][4]:
        wins_array[1] = wins_array[1] + 1
    else:
        wins_array[9] = wins_array[9] + 1

    #Tommy vs. Herbin
    if scores_array[5][4] > scores_array[8][4]:
        wins_array[5] = wins_array[5] + 1
    else:
        wins_array[8] = wins_array[8] + 1
        
    return wins_array

# %%
def week6(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Jay
    if scores_array[4][5] > scores_array[11][5]:
        wins_array[4] = wins_array[4]+ 1
    else:
        wins_array[11] = wins_array[11]+ 1
    
    #Mike vs. Will    
    if scores_array[6][5] > scores_array[3][5]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[3] = wins_array[3] + 1
    
    #Wolf vs. Eli
    if scores_array[2][5] > scores_array[10][5]:
        wins_array[2] = wins_array[2]+ 1
    else:
        wins_array[10] = wins_array[10]+ 1
           
    #Jasjaap vs. Herbin
    if scores_array[0][5] > scores_array[8][5]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[8] = wins_array[8] + 1
    
    #Cam vs. Todd
    if scores_array[1][5] > scores_array[7][5]:
        wins_array[1] = wins_array[1] + 1
    else:
        wins_array[7] = wins_array[7] + 1

    #Tommy vs. Burnett
    if scores_array[5][5] > scores_array[9][5]:
        wins_array[5] = wins_array[5] + 1
    else:
        wins_array[9] = wins_array[9] + 1
        
    return wins_array

# %%
def week7(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Will
    if scores_array[4][6] > scores_array[3][6]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[3] = wins_array[3] + 1
    
    #Mike vs. Cam    
    if scores_array[6][6] > scores_array[1][6]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Wolf vs. Jay
    if scores_array[2][6] > scores_array[11][6]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[11] = wins_array[11] + 1
           
    #Jasjaap vs. Eli
    if scores_array[0][6] > scores_array[10][6]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[10] = wins_array[10] + 1
    
    #Tommy vs. Todd
    if scores_array[5][6] > scores_array[7][6]:
        wins_array[5] = wins_array[5] + 1
    else:
        wins_array[7] = wins_array[7] + 1

    #Burnett vs. Herbin
    if scores_array[9][6] > scores_array[8][6]:
        wins_array[9] = wins_array[9] + 1
    else:
        wins_array[8] = wins_array[8] + 1
        
    return wins_array

# %%
def week8(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Cam
    if scores_array[4][7] > scores_array[1][7]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Mike vs. Tommy    
    if scores_array[6][7] > scores_array[5][7]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[5] = wins_array[5] + 1
    
    #Wolf vs. Will
    if scores_array[2][7] > scores_array[3][7]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[3] = wins_array[3] + 1
           
    #Jasjaap vs. Jay
    if scores_array[0][7] > scores_array[11][7]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[11] = wins_array[11] + 1
    
    #Eli vs. Herbin
    if scores_array[10][7] > scores_array[8][7]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[8] = wins_array[8] + 1

    #Burnett vs. Todd
    if scores_array[9][7] > scores_array[7][7]:
        wins_array[9] = wins_array[9] + 1
    else:
        wins_array[7] = wins_array[7]+ 1
        
    return wins_array

# %%
def week9(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Tommy
    if scores_array[4][8] > scores_array[5][8]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[5] = wins_array[5] + 1
    
    #Mike vs. Burnett    
    if scores_array[6][8] > scores_array[9][8]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Wolf vs. Cam
    if scores_array[2][8] > scores_array[1][8]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[1] = wins_array[1] + 1
           
    #Jasjaap vs. Will
    if scores_array[0][8] > scores_array[3][8]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[3] = wins_array[3] + 1
    
    #Eli vs. Jay
    if scores_array[10][8] > scores_array[11][8]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[11] = wins_array[11] + 1

    #Todd vs. Herbin
    if scores_array[7][8] > scores_array[8][8]:
        wins_array[7] = wins_array[7] + 1
    else:
        wins_array[8] = wins_array[8] + 1
        
    return wins_array

# %%
def week10(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Burnett
    if scores_array[4][9] > scores_array[9][9]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Mike vs. Todd    
    if scores_array[6][9] > scores_array[7][9]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[7] = wins_array[7] + 1
    
    #Wolf vs. Tommy
    if scores_array[2][9] > scores_array[5][9]:
        wins_array[2] = wins_array[2]+ 1
    else:
        wins_array[5] = wins_array[5]+ 1
           
    #Jasjaap vs. Cam
    if scores_array[0][9] > scores_array[1][9]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Eli vs. Will
    if scores_array[10][9] > scores_array[3][9]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[3] = wins_array[3] + 1

    #Jay vs. Herbin
    if scores_array[11][9] > scores_array[8][9]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[8] = wins_array[8] + 1
        
    return wins_array

# %%
def week11(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Todd
    if scores_array[4][10] > scores_array[7][10]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[7] = wins_array[7] + 1
    
    #Mike vs. Herbin    
    if scores_array[6][10] > scores_array[8][10]:
        wins_array[6] = wins_array[6]+ 1
    else:
        wins_array[8] = wins_array[8] + 1
    
    #Wolf vs. Burnett
    if scores_array[2][10] > scores_array[9][10]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[9] = wins_array[9] + 1
           
    #Jasjaap vs. Tommy
    if scores_array[0][10] > scores_array[5][10]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[5] = wins_array[5] + 1
    
    #Eli vs. Cam
    if scores_array[10][10] > scores_array[1][10]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[1] = wins_array[1]+ 1

    #Jay vs. Will
    if scores_array[11][10] > scores_array[3][10]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[3] = wins_array[3] + 1
        
    return wins_array

# %%
def week12(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Mike
    if scores_array[4][11] > scores_array[6][11]:
        wins_array[4] = wins_array[4]+ 1
    else:
        wins_array[6] = wins_array[6]+ 1
    
    #Wolf vs. Todd    
    if scores_array[2][11] > scores_array[7][11]:
        wins_array[2] = wins_array[2]+ 1
    else:
        wins_array[7] = wins_array[7] + 1
    
    #Jasjaap vs. Burnett
    if scores_array[0][11] > scores_array[9][11]:
        wins_array[0] = wins_array[0]+ 1
    else:
        wins_array[9] = wins_array[9] + 1
        
    #Eli vs. Tommy
    if scores_array[10][11] > scores_array[5][11]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    #Jay vs. Cam
    if scores_array[11][11] > scores_array[1][11]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[1] = wins_array[1] + 1
    
    #Will vs. Herbin
    if scores_array[3][11] > scores_array[8][11]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[8] = wins_array[8]+ 1
        
    return wins_array

# %%
def week13(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Herbin
    if scores_array[4][12] > scores_array[8][12]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[8] = wins_array[8] + 1
    
    #Mike vs. Wolf    
    if scores_array[6][12] > scores_array[2][12]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[2] = wins_array[2] + 1
    
    #Jasjaap vs. Todd
    if scores_array[0][12] > scores_array[7][12]:
        wins_array[0] = wins_array[0] + 1
    else:
        wins_array[7] = wins_array[7] + 1
        
    #Eli vs. Burnett
    if scores_array[10][12] > scores_array[9][12]:
        wins_array[10] = wins_array[10]+ 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Jay vs. Tommy
    if scores_array[11][12] > scores_array[5][12]:
        wins_array[11] = wins_array[11]+ 1
    else:
        wins_array[5] = wins_array[5] + 1
    
    #Will vs. Cam
    if scores_array[3][12] > scores_array[1][12]:
        wins_array[3] = wins_array[3]+ 1
    else:
        wins_array[1] = wins_array[1]+ 1
    return wins_array

# %%
def week14(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Wolf
    if scores_array[4][13] > scores_array[2][13]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[2] = wins_array[2]+ 1
    
    #Mike vs. Jasjaap    
    if scores_array[6][13] > scores_array[0][13]:
        wins_array[6] = wins_array[6]+ 1
    else:
        wins_array[0] = wins_array[0] + 1
    
    #Eli vs. Todd
    if scores_array[10][13] > scores_array[7][13]:
        wins_array[10] = wins_array[10] + 1
    else:
        wins_array[7] = wins_array[7] + 1
        
    #Jay vs. Burnett
    if scores_array[11][13] > scores_array[9][13]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[9] = wins_array[9] + 1
    
    #Will vs. Tommy
    if scores_array[3][13] > scores_array[5][13]:
        wins_array[3] = wins_array[3]+ 1
    else:
        wins_array[5] = wins_array[5]+ 1
    
    #Cam vs. Herbin
    if scores_array[1][13] > scores_array[8][13]:
        wins_array[1] = wins_array[1]+ 1
    else:
        wins_array[8] = wins_array[8]+ 1
    return wins_array

# %%
def week15(scores_array, wins_array):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    #Brenton vs. Jasjaap
    if scores_array[4][14] > scores_array[0][14]:
        wins_array[4] = wins_array[4] + 1
    else:
        wins_array[0] = wins_array[0] + 1
    
    #Mike vs. Eli    
    if scores_array[6][14] > scores_array[10][14]:
        wins_array[6] = wins_array[6] + 1
    else:
        wins_array[10] = wins_array[10] + 1
    
    #Wolf vs. Herbin
    if scores_array[2][14] > scores_array[8][14]:
        wins_array[2] = wins_array[2] + 1
    else:
        wins_array[8] = wins_array[8] + 1
           
    #Jay vs. Todd
    if scores_array[11][14] > scores_array[7][14]:
        wins_array[11] = wins_array[11] + 1
    else:
        wins_array[7] = wins_array[7] + 1
    
    #Will vs. Burnett
    if scores_array[3][14] > scores_array[9][14]:
        wins_array[3] = wins_array[3] + 1
    else:
        wins_array[9] = wins_array[9] + 1

    #Cam vs. Tommy
    if scores_array[1][14] > scores_array[5][14]:
        wins_array[1] = wins_array[1] + 1
    else:
        wins_array[5] = wins_array[5] + 1
        
    return wins_array

# %%
def week_fair(scores_array, wins_array, week = 12):
    Teams = {'Jasjaap':0, 'Cam':1, 'Wolf':2, 'Will':3, 'Brenton':4, 'Tommy':5, 'Mike':6,
            'Todd':7, 'Herbin':8, 'Burnett':9, 'Eli':10, 'Jay': 11} #not used, just for reference
    
    p = np.arange(12)
    random.shuffle(p)
    
    for n in range(6):
        first = p[2*n]
        second = p[2*n+1]
    
        if scores_array[first][week-1] > scores_array[second][week-1]:
            wins_array[first] = wins_array[first] + 1
        else:
            wins_array[second] = wins_array[second] + 1
    
    return wins_array

# %%
def simulate_one_season_matchups(scoring_array, fair=False):
    wins_array = np.zeros(12)
    WINS1 = week1(scoring_array, wins_array.copy())
    WINS2 = week2(scoring_array, WINS1.copy())
    WINS3 = week3(scoring_array, WINS2.copy())
    WINS4 = week4(scoring_array, WINS3.copy())
    WINS5 = week5(scoring_array, WINS4.copy())
    WINS6 = week6(scoring_array, WINS5.copy())
    WINS7 = week7(scoring_array, WINS6.copy())
    WINS8 = week8(scoring_array, WINS7.copy())
    WINS9 = week9(scoring_array, WINS8.copy())
    WINS10 = week10(scoring_array, WINS9.copy())
    WINS11 = week11(scoring_array, WINS10.copy())
    
    if fair==False:
        WINS12 = week12(scoring_array, WINS11.copy())
        WINS13 = week13(scoring_array, WINS12.copy())
        WINS14 = week14(scoring_array, WINS13.copy())
        wins_per_team = tuple(week15(scoring_array, WINS14.copy()))
    elif fair==True:
        WINS12 = week_fair(scoring_array, WINS11.copy(), week=12)
        WINS13 = week_fair(scoring_array, WINS12.copy(), week=13)
        WINS14 = week_fair(scoring_array, WINS13.copy(), week=14)
        wins_per_team = tuple(week_fair(scoring_array, WINS14.copy(), week=15))

    #return final results
    losses_per_team = tuple([15-w for w in wins_per_team])
    score_per_team = tuple(scoring_array.sum(axis=1))
    label_per_team =  tuple(FF_2021_summary['Team_Name'])
    standings = pd.DataFrame(np.vstack((wins_per_team, losses_per_team, score_per_team)).T, index=label_per_team)
    standings = standings.rename(columns={0:'W', 1:'L', 2:'Pts'})    
    
    standings['Pts'] = standings['Pts'].astype(float)
    standings = standings.sort_values(by=['W', 'Pts'], ascending=[False, False])
    
    standings['Place'] = np.arange(1,13)
    standings['Playoffs'] = np.where(standings['Place'] < 5, 1, 0)
    standings['Top'] = np.where(standings['Place'] == 1, 1, 0)
    standings['Sacko'] = np.where(standings['Place'] == 12, 1, 0)
    
    places = np.array(standings['Place'])
    playoffs = np.array(standings['Playoffs'])
    tops = np.array(standings['Top'])
    sackos = np.array(standings['Sacko'])
    
    return standings

# %%
def simulate_many_seasons(FF_summary, sims = 2, fair=False):
    '''
    @sims is the number of simulations you would like to run.
    '''
    SCORES = simulate_one_season_scores(FF_summary)
    TOTAL = simulate_one_season_matchups(SCORES, fair=fair)
    
    for i in range(1,sims):
            
        SCORES = simulate_one_season_scores(FF_summary)
        SEASON_DF = simulate_one_season_matchups(SCORES, fair=fair)
        
        for col in TOTAL.columns.values:
            TOTAL[col] = TOTAL[col]/(i+1)*i + SEASON_DF[col]/(i+1) #Average is continusously updated across trials
    return TOTAL

def clean_total(total):
    total['W'] = round(total['W'], 2)
    total['L'] = 15-total['W']
    total['Pts'] = round(total['Pts'], 2)
    total['Place'] = round(total['Place'], 2)
    total['Playoffs'] = round(total['Playoffs'], 3)*100
    total['Top'] = round(total['Top'], 3)*100
    total['Sacko'] = round(total['Sacko'], 3)*100
    total = total.sort_values(by='Place')
    return total

# %% [markdown]
# # Run simulations

# %%
Sims = simulate_many_seasons(FF_2021_summary, sims = 100000)
Sims = clean_total(Sims)

# %%
print(sum(Sims['W']), sum(Sims['L']))
Sims
# Out:
# 89.97000000000001 90.02999999999999
#                            W      L      Pts  Place  Playoffs   Top  Sacko
# Pay Dirt and Pylons    10.22   4.78  1891.84   2.68      83.0  38.3    0.0
# Jasjaap's Primo Team    9.15   5.85  1823.08   4.06      62.3  15.6    0.2
# GOBias Industries       8.96   6.04  1813.98   4.32      58.1  13.5    0.3
# Dak to Dak              8.91   6.09  1807.47   4.39      56.5  12.8    0.2
# Brady = Washed Up III   8.68   6.32  1787.39   4.76      50.7  10.2    0.3
# Gee Whiz Darnell        7.56   7.44  1722.49   6.43      26.1   3.4    1.3
# Herbin Legends          7.28   7.72  1705.00   6.85      21.2   2.4    1.8
# Shiva Volodarskaya      7.32   7.68  1663.21   7.02      19.0   1.9    2.1
# Schmop                  6.78   8.22  1619.72   7.84      11.8   1.0    4.2
# Sackwash Lyfe           6.60   8.40  1610.14   8.10       9.8   0.8    4.9
# Champagne or Bust       4.84  10.16  1480.40  10.25       1.3   0.0   23.7
# ...

# %%
Sims.to_excel('SimsRegular21.xlsx')

# %%
Sims2 = simulate_many_seasons(FF_2021_summary, sims = 100000, fair=True)
Sims2 = clean_total(Sims2)

# %%
print(sum(Sims2['W']), sum(Sims2['L']))
Sims2
# Out:
# 89.99999999999999 90.00000000000001
#                            W      L      Pts  Place  Playoffs   Top  Sacko
# Pay Dirt and Pylons    10.08   4.92  1891.90   2.87      80.1  34.7    0.0
# Jasjaap's Primo Team    9.21   5.79  1823.30   4.03      62.1  16.5    0.1
# GOBias Industries       9.09   5.91  1813.98   4.21      59.3  14.6    0.2
# Dak to Dak              9.02   5.98  1807.84   4.32      57.3  13.4    0.2
# Brady = Washed Up III   8.74   6.26  1787.23   4.73      50.5  10.4    0.3
# Gee Whiz Darnell        7.88   7.12  1722.42   6.08      30.0   4.2    0.9
# Herbin Legends          7.65   7.35  1705.08   6.43      25.6   3.3    1.2
# Shiva Volodarskaya      7.09   7.91  1662.81   7.30      16.0   1.6    2.3
# Schmop                  6.52   8.48  1619.67   8.13       9.4   0.8    4.5
# Sackwash Lyfe           6.38   8.62  1609.82   8.31       8.4   0.6    5.2
# Champagne or Bust       4.74  10.26  1480.02  10.30       1.1   0.0   24.1
# ...

# %%
Sims2.to_excel('SimsRandom21.xlsx')
